# %% [markdown]
# # Advanced Spotify Data Analysis and Interpretation🔍🎧
#
#
# ## The Formula to success

# %% [markdown]
# ![spotify2.png](attachment:spotify2.png)

# %% [markdown]
# The Dataset we're working with consists of 953 Rows(Songs) and 24 Columns.The Goal of this Analysis is to get an overview of musical trends throughout spotify and find some interesting correlations.
# This Dataset is available on [Kaggle](https://www.kaggle.com/code/amr7ac/popular-spotify-songs-analysis).Let's
# briefly talk about our Dataset before we get started.

# %% [markdown]
# In our Dataset there are 24 columns:
#
# * ```track_name```: **The name of the track.**
#
#
# * ```artist(s)_name```: **The name(s) of the artist(s) who created the track.**
#
#
#
# * ```artist_count```: **The number of artists associated with the track.**
#
# * ```released_year```: **The year when the track was released.**
#
# * ```released_month```: **The month when the track was released.**
#
# * ```released_day```: **The day when the track was released.**
#
# * ```in_spotify_playlists```: **Indicates whether the track is included in Spotify playlists.**
#
# * ```in_spotify_charts```: **Indicates whether the track is present in Spotify charts.**
#
# * ```streams```:**The total number of streams the track has accumulated.**
#
# * ```in_apple_playlists```: **Indicates whether the track is included in Apple Music playlists.**
#
# * ```in_apple_charts```: **Indicates whether the track is present in Apple Music charts.**
#
# * ```in_deezer_playlists```: **Indicates whether the track is included in Deezer playlists.**
#
# * ```in_deezer_charts```: **Indicates whether the track is present in Deezer charts.**
#
# * ```in_shazam_charts```: **Indicates whether the track is present in Shazam charts.**
#
# * ```bpm```: **Beats per minute - a measure of tempo in music.**
#
# * ```key```: **The musical key in which the track is composed.**
#
# * ```mode```: **Indicates whether the track is in a major or minor key.**
#
# * ```danceability_```: **A measure of how suitable a track is for dancing.**
#
# * ```valence_```: **The musical positiveness conveyed by a track.**
#
# * ```energy_```: **The perceived energy of a track.**
#
# * ```acousticness_```: **A measure of how acoustic a track is.**
#
# * ```instrumentalness_```: **A measure of whether a track contains vocals.**
#
# * ```liveness_speechiness_```: **A measure of presence of live elements or spoken words in a track.**

# %% [markdown]
# Without further ado, let's get started!📝

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('D:\\Desktop\\Projects\\SpotifyAnalysis\\Popular_Spotify_Songs.csv', encoding_errors = 'ignore')
df
# Out:
#                               track_name      artist(s)_name  artist_count  \
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook             2
# 1                                   LALA         Myke Towers             1
# 2                                vampire      Olivia Rodrigo             1
# 3                           Cruel Summer        Taylor Swift             1
# 4                         WHERE SHE GOES           Bad Bunny             1
# ..                                   ...                 ...           ...
# 948                         My Mind & Me        Selena Gomez             1
# 949            Bigger Than The Whole Sky        Taylor Swift             1
# 950                 A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951                        En La De Ella  Feid, Sech, Jhayco             3
# 952                                Alone           Burna Boy             1
#
# ...

# %% [markdown]
# ## General Information about the Dataset

# %%
df.describe()
# Out:
#        artist_count  released_year  released_month  released_day  \
# count    953.000000     953.000000      953.000000    953.000000
# mean       1.556139    2018.238195        6.033578     13.930745
# std        0.893044      11.116218        3.566435      9.201949
# min        1.000000    1930.000000        1.000000      1.000000
# 25%        1.000000    2020.000000        3.000000      6.000000
# 50%        1.000000    2022.000000        6.000000     13.000000
# 75%        2.000000    2022.000000        9.000000     22.000000
# max        8.000000    2023.000000       12.000000     31.000000
#
#        in_spotify_playlists  in_spotify_charts       streams  \
# count            953.000000         953.000000  9.530000e+02
# mean            5200.124869          12.009444  5.135979e+08
# std             7897.608990          19.575992  5.668039e+08
# min               31.000000           0.000000  0.000000e+00
# 25%              875.000000           0.000000  1.413817e+08
# ...

# %%
df.columns
# Out:
# Index(['track_name', 'artist(s)_name', 'artist_count', 'released_year',
#        'released_month', 'released_day', 'in_spotify_playlists',
#        'in_spotify_charts', 'streams', 'in_apple_playlists', 'in_apple_charts',
#        'in_deezer_playlists', 'in_deezer_charts', 'in_shazam_charts', 'bpm',
#        'key', 'mode', 'danceability_%', 'valence_%', 'energy_%',
#        'acousticness_%', 'instrumentalness_%', 'liveness_%', 'speechiness_%'],
#       dtype='object')

# %%
df.head(8)
# Out:
#                             track_name              artist(s)_name  \
# 0  Seven (feat. Latto) (Explicit Ver.)            Latto, Jung Kook
# 1                                 LALA                 Myke Towers
# 2                              vampire              Olivia Rodrigo
# 3                         Cruel Summer                Taylor Swift
# 4                       WHERE SHE GOES                   Bad Bunny
# 5                             Sprinter           Dave, Central Cee
# 6                      Ella Baila Sola  Eslabon Armado, Peso Pluma
# 7                             Columbia                     Quevedo
#
#    artist_count  released_year  released_month  released_day  \
# 0             2           2023               7            14
# 1             1           2023               3            23
# 2             1           2023               6            30
# 3             1           2019               8            23
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 953 entries, 0 to 952
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   track_name            951 non-null    object
#  1   artist(s)_name        953 non-null    object
#  2   artist_count          953 non-null    int64
#  3   released_year         953 non-null    int64
#  4   released_month        953 non-null    int64
#  5   released_day          953 non-null    int64
#  6   in_spotify_playlists  953 non-null    int64
#  7   in_spotify_charts     953 non-null    int64
#  8   streams               953 non-null    int64
#  9   in_apple_playlists    953 non-null    int64
#  10  in_apple_charts       953 non-null    int64
#  11  in_deezer_playlists   953 non-null    object
#  12  in_deezer_charts      953 non-null    int64
#  13  in_shazam_charts      903 non-null    object
#  14  bpm                   953 non-null    int64
# ...

# %%
df.isnull().sum()
# Out:
# track_name               2
# artist(s)_name           0
# artist_count             0
# released_year            0
# released_month           0
# released_day             0
# in_spotify_playlists     0
# in_spotify_charts        0
# streams                  0
# in_apple_playlists       0
# in_apple_charts          0
# in_deezer_playlists      0
# in_deezer_charts         0
# in_shazam_charts        50
# bpm                      0
# key                     95
# mode                     0
# danceability_%           0
# valence_%                0
# energy_%                 0
# acousticness_%           0
# instrumentalness_%       0
# liveness_%               0
# speechiness_%            0
# dtype: int64

# %% [markdown]
# ## Top 10 Tracks by streams

# %%
top_ten_tracks = df.sort_values(by='streams', ascending=False).head(10)
top_ten_tracks
# Out:
#                                         track_name  \
# 55                                 Blinding Lights
# 179                                   Shape of You
# 86                               Someone You Loved
# 620                                   Dance Monkey
# 41   Sunflower - Spider-Man: Into the Spider-Verse
# 162                                      One Dance
# 84                       STAY (with Justin Bieber)
# 140                                       Believer
# 725                                         Closer
# 48                                         Starboy
#
#                    artist(s)_name  artist_count  released_year  \
# 55                     The Weeknd             1           2019
# 179                    Ed Sheeran             1           2017
# 86                  Lewis Capaldi             1           2018
# 620                   Tones and I             1           2019
# 41          Post Malone, Swae Lee             2           2018
# ...

# %%
crosstab_result = pd.crosstab(index=top_ten_tracks['key'], columns='count').rename_axis(None, axis=1)

crosstab_result
# Out:
#      count
# key
# A#       1
# C#       5
# D        1
# F#       1
# G        1
# G#       1

# %% [markdown]
# Interestingly enough 5 out of these Top 10 Songs are written in `C#` and 4 of them in `C# Major`.
# > Since i am very well versed in music theory i have a few things to note about this.
# > We can also see that <mark>8 out of these 10 Songs</mark> are written in `altered(raised/lowered) keys`.
# > `Sharp keys` tend to sound more playful and bright while `Flat keys` sound more warm and in place than our usual `C Major  Scale`(better to say the notes of the scale).
# > So to say since a sharp/flat in front of a note raises/lowers it by a half step, commonly songs in a `sharp major` key appear to be more <mark>brighter and playful</mark> and songs written in `flat major` key appear more <mark>calm and  warm.</mark>
#
#
# Also interesting to note is, that none of the all time Top 10 Songs(Based on Spotify Streams) are written in the most simple and common key `C Major`.
#
# Let's dive deeper into the concept of how Keys and Modes might influence the popularity of a song at a later time in this analysis.

# %% [markdown]
# Before we dive deeper, we overviewed our Data but let's now take a few moments to get it in Shape!

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# We notice that we have 3 columns, ```released_year```, ```released_month``` and ```released_day```, which we can and have to merge together and parse this as a date.This will help us immensely, when diving deeper into the analysis part.

# %%
df.dropna()
df
# Out:
#                               track_name      artist(s)_name  artist_count  \
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook             2
# 1                                   LALA         Myke Towers             1
# 2                                vampire      Olivia Rodrigo             1
# 3                           Cruel Summer        Taylor Swift             1
# 4                         WHERE SHE GOES           Bad Bunny             1
# ..                                   ...                 ...           ...
# 948                         My Mind & Me        Selena Gomez             1
# 949            Bigger Than The Whole Sky        Taylor Swift             1
# 950                 A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951                        En La De Ella  Feid, Sech, Jhayco             3
# 952                                Alone           Burna Boy             1
#
# ...

# %%
df = df.drop_duplicates()
df.shape
# Out:
# (953, 24)

# %%
df = df.dropna(subset=['released_year', 'released_month', 'released_day'])
df.shape
# Out:
# (953, 24)

# %%
print(df[(df['released_year'] < 1900) | (df['released_year'] > 2024)])
print(df[(df['released_month'] < 1) | (df['released_month'] > 12)])
print(df[(df['released_day'] < 1) | (df['released_day'] > 31)])

df.info()
# Out:
# Empty DataFrame
# Columns: [track_name, artist(s)_name, artist_count, released_year, released_month, released_day, in_spotify_playlists, in_spotify_charts, streams, in_apple_playlists, in_apple_charts, in_deezer_playlists, in_deezer_charts, in_shazam_charts, bpm, key, mode, danceability_%, valence_%, energy_%, acousticness_%, instrumentalness_%, liveness_%, speechiness_%]
# Index: []
#
# [0 rows x 24 columns]
# Empty DataFrame
# Columns: [track_name, artist(s)_name, artist_count, released_year, released_month, released_day, in_spotify_playlists, in_spotify_charts, streams, in_apple_playlists, in_apple_charts, in_deezer_playlists, in_deezer_charts, in_shazam_charts, bpm, key, mode, danceability_%, valence_%, energy_%, acousticness_%, instrumentalness_%, liveness_%, speechiness_%]
# Index: []
#
# [0 rows x 24 columns]
# Empty DataFrame
# ...

# %% [markdown]
# Small problems seem to appear when trying to create a ```release_date``` column, lets fix it!

# %%
try:
    df['release_date'] = df.apply(lambda row: pd.to_datetime({
        'year': row['released_year'],
        'month': row['released_month'],
        'day': row['released_day']
    }), axis=1)
except Exception as e:
    print("Error in converting to datetime:", e)
# Out:
# Error in converting to datetime: If using all scalar values, you must pass an index

# %%
df['release_date_str'] = df['released_year'].astype(str) + '-' + df['released_month'].astype(str).str.zfill(2) + '-' + df['released_day'].astype(str).str.zfill(2)

# Convert the combined string column to datetime
try:
    df['release_date'] = pd.to_datetime(df['release_date_str'])
    df.drop(columns=['release_date_str'], inplace=True)
except Exception as e:
    print("Error in converting to datetime:", e)
    
df
# Out:
#                               track_name      artist(s)_name  artist_count  \
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook             2
# 1                                   LALA         Myke Towers             1
# 2                                vampire      Olivia Rodrigo             1
# 3                           Cruel Summer        Taylor Swift             1
# 4                         WHERE SHE GOES           Bad Bunny             1
# ..                                   ...                 ...           ...
# 948                         My Mind & Me        Selena Gomez             1
# 949            Bigger Than The Whole Sky        Taylor Swift             1
# 950                 A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951                        En La De Ella  Feid, Sech, Jhayco             3
# 952                                Alone           Burna Boy             1
#
# ...

# %%
df.drop(columns = ['released_year', 'released_month', 'released_day'], inplace = True)
df
# Out:
#                               track_name      artist(s)_name  artist_count  \
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook             2
# 1                                   LALA         Myke Towers             1
# 2                                vampire      Olivia Rodrigo             1
# 3                           Cruel Summer        Taylor Swift             1
# 4                         WHERE SHE GOES           Bad Bunny             1
# ..                                   ...                 ...           ...
# 948                         My Mind & Me        Selena Gomez             1
# 949            Bigger Than The Whole Sky        Taylor Swift             1
# 950                 A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951                        En La De Ella  Feid, Sech, Jhayco             3
# 952                                Alone           Burna Boy             1
#
# ...

# %%
pd.set_option('display.max_columns', None)
df
# Out:
#                               track_name      artist(s)_name  artist_count  \
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook             2
# 1                                   LALA         Myke Towers             1
# 2                                vampire      Olivia Rodrigo             1
# 3                           Cruel Summer        Taylor Swift             1
# 4                         WHERE SHE GOES           Bad Bunny             1
# ..                                   ...                 ...           ...
# 948                         My Mind & Me        Selena Gomez             1
# 949            Bigger Than The Whole Sky        Taylor Swift             1
# 950                 A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951                        En La De Ella  Feid, Sech, Jhayco             3
# 952                                Alone           Burna Boy             1
#
# ...

# %%
df['in_deezer_playlists'] = pd.to_numeric(df['in_deezer_playlists'], errors='coerce')
df['in_shazam_charts'] = pd.to_numeric(df['in_shazam_charts'], errors='coerce')

# %%
df.isnull().sum()
# Out:
# track_name               2
# artist(s)_name           0
# artist_count             0
# in_spotify_playlists     0
# in_spotify_charts        0
# streams                  0
# in_apple_playlists       0
# in_apple_charts          0
# in_deezer_playlists     79
# in_deezer_charts         0
# in_shazam_charts        57
# bpm                      0
# key                     95
# mode                     0
# danceability_%           0
# valence_%                0
# energy_%                 0
# acousticness_%           0
# instrumentalness_%       0
# liveness_%               0
# speechiness_%            0
# release_date             0
# dtype: int64

# %%
df.dropna(subset=['track_name', 'streams', 'in_deezer_playlists', 'in_shazam_charts', 'key'], inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 747 entries, 0 to 952
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   track_name            747 non-null    object
#  1   artist(s)_name        747 non-null    object
#  2   artist_count          747 non-null    int64
#  3   in_spotify_playlists  747 non-null    int64
#  4   in_spotify_charts     747 non-null    int64
#  5   streams               747 non-null    int64
#  6   in_apple_playlists    747 non-null    int64
#  7   in_apple_charts       747 non-null    int64
#  8   in_deezer_playlists   747 non-null    float64
#  9   in_deezer_charts      747 non-null    int64
#  10  in_shazam_charts      747 non-null    float64
#  11  bpm                   747 non-null    int64
#  12  key                   747 non-null    object
#  13  mode                  747 non-null    object
#  14  danceability_%        747 non-null    int64
# ...

# %%
df.head(10)
# Out:
#                             track_name              artist(s)_name  \
# 0  Seven (feat. Latto) (Explicit Ver.)            Latto, Jung Kook
# 1                                 LALA                 Myke Towers
# 2                              vampire              Olivia Rodrigo
# 3                         Cruel Summer                Taylor Swift
# 4                       WHERE SHE GOES                   Bad Bunny
# 5                             Sprinter           Dave, Central Cee
# 6                      Ella Baila Sola  Eslabon Armado, Peso Pluma
# 7                             Columbia                     Quevedo
# 8                             fukumean                       Gunna
# 9                      La Bebe - Remix       Peso Pluma, Yng Lvcas
#
#    artist_count  in_spotify_playlists  in_spotify_charts    streams  \
# 0             2                   553                147  141381703
# 1             1                  1474                 48  133716286
# ...

# %%
#get these two also as an int value
df.in_shazam_charts = df.in_shazam_charts.astype(int)
df.in_deezer_playlists = df.in_deezer_playlists.astype(int)
df
# Out:
#                               track_name      artist(s)_name  artist_count  \
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook             2
# 1                                   LALA         Myke Towers             1
# 2                                vampire      Olivia Rodrigo             1
# 3                           Cruel Summer        Taylor Swift             1
# 4                         WHERE SHE GOES           Bad Bunny             1
# ..                                   ...                 ...           ...
# 948                         My Mind & Me        Selena Gomez             1
# 949            Bigger Than The Whole Sky        Taylor Swift             1
# 950                 A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951                        En La De Ella  Feid, Sech, Jhayco             3
# 952                                Alone           Burna Boy             1
#
# ...

# %% [markdown]
# Now that our Data is cleaned, we are ready for analyzing and visualizing!✅

# %% [markdown]
# ## Visualization
# ### 1.Overview

# %%
#so the warnings about future versions will get filtered in this notebook
import warnings
warnings.filterwarnings('ignore')

spotify_green = ["#1DB954"]

# get the color scheme
sns.set_palette(spotify_green)

# Plot the numerical values
numerical_columns = ['streams', 'in_spotify_playlists', 'in_spotify_charts', 'in_apple_playlists', 'in_apple_charts',
                     'in_deezer_playlists', 'in_deezer_charts', 'in_shazam_charts', 'bpm', 'danceability_%', 'valence_%',
                     'energy_%', 'acousticness_%', 'instrumentalness_%', 'liveness_%', 'speechiness_%']

plt.figure(figsize=(15, 20))
for i, col in enumerate(numerical_columns, 1):
    plt.subplot(5, 4, i)
    sns.histplot(df[col], kde=True, bins=30)
    plt.title(f'Distribution of {col}')
plt.tight_layout()
plt.show()

# %% [markdown]
# Since this Data now consists of about 750 Songs, whiches choosing to be in this dataset didn't really follow a scheme(more like a slightly popularity-based random sample focusing on 2022), we cant really gather a lot of deep insights on some question but we will still try our best!

# %%
import warnings
warnings.filterwarnings('ignore')

green_palette = ["#1DB954", "#1ED760", "#21C564", "#24B268", "#27A86C"] 

# set the scheme
sns.set_palette(green_palette)

# Plot counts for categorical features
categorical_columns = ['artist_count', 'release_year', 'key', 'mode']

# get release year from dt column
df['release_year'] = df['release_date'].dt.year

plt.figure(figsize=(15, 12))
for i, col in enumerate(categorical_columns, 1):
    plt.subplot(3, 2, i)
    # get the percent counts
    total_count = len(df[col])
    counts = df[col].value_counts(normalize=True) * 100
    sns.barplot(x=counts.index, y=counts.values, order=counts.index, palette=green_palette)
    plt.title(f'Percentage of {col}')
    plt.xlabel(col)
    plt.ylabel('Percentage')
    plt.xticks(rotation=90)
    plt.ylim(0, 100)  
    plt.tight_layout()

plt.show()

# %%
# get a noce color scheme
green_palette = ["#1DB954", "#1ED760", "#21C564", "#24B268", "#27A86C", "#2AA170", "#2DA974"]  

# set it
sns.set_palette(green_palette)

# extract the days
df['weekday'] = df['release_date'].dt.day_name()

# plot the weekday release numbers
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='weekday', order=['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'])
plt.title('Count of Releases by Weekday')
plt.xlabel('Weekday')
plt.ylabel('Count')
plt.xticks(rotation=45)  # rotate for better visuals
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Findings🕵🏼‍♂️
# ### Bold Overview Findings

# %% [markdown]
# Since i don't want this project for future hirers to be a 200 page long essay I will in the following briefly explain what interesting things we can see regarding those plots and maybe at the end of this analysis we can conclude a rough **"Formula to Success"**.Let's find out!

# %% [markdown]
# >* most of the songs are set between **80 - 150 BPM**
# >* a lot of songs share a high danceability/valence/energy **~ 40 - 90%**
# >* acousticness appears to be **very low**, which reinforces the statement made above

# %% [markdown]
# ### Categorical Analysis Findings

# %% [markdown]
# * around 60% are single artist songs and around 25% are performed by two artists or more
# * the release year doesnt really give us much insights because the Dataset is highly focused around the year 2022
# * as we saw before in the top 10, C#/Db seems to be a very popular key followed by G and F
# * the percentiles for songs in  minor and major keys appear to be very close together

# %% [markdown]
# ### Weekday Analysis Findings

# %% [markdown]
# We can see, that a vast majority of the songs gets released either Friday or Thursday.This has several reasons:
# ***
#
# 1. ✳️**New Music Friday Playlists**: Spotify and other streaming services feature curated playlists like "New Music Friday," which showcase new releases. By releasing music on Thursday night (which aligns with Friday in many time zones), artists can ensure their songs are included in these highly trafficked playlists right from the start of the release period, maximizing visibility.
# ***
# 2. ✳️**Chart Tracking**: The music industry tracks sales and streams on a weekly basis, typically from Friday to Thursday. Releasing music at the beginning of this period (Friday) gives songs the maximum amount of time to accumulate streams and sales, which can impact chart positions on platforms like the Billboard Hot 100.
# ***
# 3. ✳️**Consumer Behavior**: People tend to have more free time to discover and listen to new music over the weekend. Releasing songs on Friday taps into this behavior, increasing the likelihood that listeners will engage with new releases when they have the time and inclination to do so.
# ***
# 4. ✳️**Global Realease Strategy**: A simultaneous global release ensures that fans around the world can access new music at the same time, reducing the risk of piracy and ensuring a more coordinated marketing push. Releasing music on Thursday night aligns with Friday in many major markets due to time zone differences.
# ***
# 5. ✳️**Weekend Promotions and Events**: Artists often plan promotional events, live performances, or media appearances around the time of a new release. Launching a song or album at the end of the week provides a natural lead-in to these promotional activities.

# %%
# just as a little reminder, we have defined that variable already
numerical_columns = ['streams', 'in_spotify_playlists', 'in_spotify_charts', 'in_apple_playlists', 'in_apple_charts',
                     'in_deezer_playlists', 'in_deezer_charts', 'in_shazam_charts', 'bpm', 'danceability_%', 'valence_%',
                     'energy_%', 'acousticness_%', 'instrumentalness_%', 'liveness_%', 'speechiness_%']

numeric_df = df[numerical_columns]

numeric_df = df[numerical_columns]

# Plot correlation heatmap
plt.figure(figsize=(12, 10))
correlation_matrix = numeric_df.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ### Interesting Properties of the Heatmap

# %% [markdown]
# * ✅rather strong correlation between the number of streams and the appearance in playlist
#     * good performing songs are logically more likely to be liked and saved by more people
#     ***
# * ✅correlation between appearance in apple/deezer playlists and spotify charts and number of streams
# ***
# * ⛔️strong anti-synergy between acousticness and energy
#     * acoustic songs tend to be calm and more soft
# ***
# * ⛔️the same for acousticness paired with danceability
# ***
# * ✅small correlation between valence and danceability

# %%
from sklearn.cluster import KMeans

import warnings
warnings.filterwarnings("ignore")

# Features for clustering
features_for_clustering = ['streams', 'in_spotify_playlists', 'in_spotify_charts',
                           'in_apple_playlists', 'in_apple_charts', 'in_deezer_playlists',
                           'in_deezer_charts', 'in_shazam_charts', 'danceability_%',
                           'valence_%', 'energy_%']

# Scatter plots for relationships between features
relationships = [
    ('streams', 'in_spotify_playlists'),
    ('streams', 'in_spotify_charts'),
    ('streams', 'in_apple_playlists'),
    ('streams', 'in_apple_charts'),
    ('streams', 'in_deezer_playlists'),
    ('streams', 'in_deezer_charts'),
    ('streams', 'in_shazam_charts'),
    ('streams', 'danceability_%'),
    ('streams', 'valence_%'),
    ('streams', 'energy_%')
]

# Clustering
kmeans = KMeans(n_clusters=3)  # Nr of clusters adjustable
df['cluster'] = kmeans.fit_predict(df[features_for_clustering])

# Plotting
plt.figure(figsize=(15, 20))
for i, (x, y) in enumerate(relationships, 1):
    plt.subplot(5, 2, i)
    sns.scatterplot(data=df, x=x, y=y, hue='cluster', palette='Set2')
    plt.title(f'{x} vs {y}')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Analytic Conclusion
#
# In conclusion, our analysis sheds light on the multifaceted aspects of successful music, encompassing factors like streaming metrics, audio attributes, categorical features, release patterns, and musical characteristics. By understanding these trends and correlations, we can begin to uncover patterns that contribute to the creation and reception of hit songs. Moving forward, delving deeper into the nuanced relationships between musical elements and audience preferences holds promise for refining our understanding of the "Formula to Success" in the music industry.
# ***
# I'm sure, that if we had a bigger and more reliable Dataset, we could've gathered a lot more insights bur for now as
# a nice training project this should do it!
# ***
# What we can say for sure tho is, that you as an upcoming artist can't go wrong by choosing C#/Db as your piece's Key.😁
